# %%
import duckdb 
import pandas as pd

# %%
db = duckdb.connect('./data/duck_pond.duckdb')

# %%
db.execute("select * from information_schema.tables").df()
# Out:
#   table_catalog table_schema                  table_name  table_type  \
# 0     duck_pond  source_data                   pond_data  BASE TABLE
# 1     duck_pond  source_data             pond_data__hits  BASE TABLE
# 2     duck_pond  source_data    pond_data__hits__product  BASE TABLE
# 3     duck_pond  source_data  pond_data__hits__promotion  BASE TABLE
# 4     duck_pond  source_data                  _dlt_loads  BASE TABLE
# 5     duck_pond  source_data         _dlt_pipeline_state  BASE TABLE
# 6     duck_pond  source_data                _dlt_version  BASE TABLE
#
#   self_referencing_column_name reference_generation user_defined_type_catalog  \
# 0                         None                 None                      None
# 1                         None                 None                      None
# 2                         None                 None                      None
# 3                         None                 None                      None
# ...
